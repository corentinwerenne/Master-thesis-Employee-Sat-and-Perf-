# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import numpy as np

# %%
# Get data
orbis = pd.read_csv('orbis_clean.csv')
orbis = orbis.drop('Unnamed: 0', axis=1)
gd = pd.read_csv('reviews/all_df.csv')
gd = gd.drop('Unnamed: 0', axis=1)
industries = pd.read_csv('industries.csv')
industries = industries.drop('Unnamed: 0', axis=1)
# Out:
# <ipython-input-2-917b4856c942>:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   gd = pd.read_csv('reviews/all_df.csv')

# %%
industries = industries.rename(columns={"Nom de l'entreprise Latin alphabet": 'name',
                                       'Numéro Orbis': 'orbis_nbr',
                                       'BvD sectors': 'bvd_sector',
                                       'Code SIC (US) Code(s) Primaire(s)': 'primary_sic',
                                       'US SIC Principal, description textuelle': 'primary_sic_txt',
                                       'Code SIC (US) Code(s) Secondaire(s)': 'secundary_sic',
                                       'US SIC secondaire, description textuelle': 'secundary_sic_txt'})

# %%
# Exclude companies with less than 30 reviews
count_companies = gd.groupby('orbis_name')['review_id'].count()
gd = gd[gd['orbis_name'].isin(count_companies[count_companies >= 30].index)]

# %%
# Complete dataset
# Merge financial and reviews and classification
orbis_gd = pd.merge(orbis, gd, left_on='name', right_on='orbis_name')
orbis_gd = pd.merge(orbis_gd, industries, on='orbis_nbr')

# %%
# Convert certain columns to numeric
def numerize_friend(string):
    if string == '"NEGATIVE"':
        return -1
    elif string == '"POSITIVE"':
        return 1
    else:
        return np.nan
    
def numerize_ceo(string):
    if string == '"DISAPPROVE"':
        return -1
    elif string == '"APPROVE"':
        return 1
    else:
        return np.nan
    
def numerize_outlook(string):
    if string == '"NEUTRAL"':
        return 0
    elif string == '"POSITIVE"':
        return 1
    elif string == '"NEGATIVE"':
        return -1
    else:
        return np.nan
    
orbis_gd['rating_recommend_friend'] = orbis_gd['rating_recommend_friend'].apply(numerize_friend)
orbis_gd['rating_ceo'] = orbis_gd['rating_ceo'].apply(numerize_ceo)
orbis_gd['rating_businessoutlook'] = orbis_gd['rating_businessoutlook'].apply(numerize_outlook)

# %% [markdown]
# ### Basic exploration

# %%
orbis_gd.shape
# Out:
# (567044, 251)

# %%
sector_counts = orbis_gd['bvd_sector'].value_counts()
sector_counts
# Out:
# Services aux entreprises                                       100377
# Machines industrielles, électriques et électroniques            83174
# Banque, assurance et services financiers                        68772
# Produits chimiques, pétrole, caoutchouc et plastique            57699
# Commerce de détail                                              53287
# Communications                                                  46901
# Fabrication des produits alimentaires et de tabac               26632
# Fabrication de transport                                        21415
# Voyage, personnel et loisirs                                    17443
# Industries extractives                                           9734
# Logiciel informatique                                            9569
# Utilitaires                                                      9102
# Fabrication des textiles et des vêtements                        8759
# Transports et entreposage                                        8480
# Commerce de gros                                                 6072
# Biotechnologie et sciences de la vie                             5788
# Métaux et produits métalliques                                   5696
# Administration publique, éducation, santé, services sociaux      4753
# Média et diffusion                                               4490
# Produits en cuir, pierre, argile et verre                        4186
# Construction                                                     4054
# Services immobiliers                                             3872
# Impression et Edition                                            3740
# Fabrication de bois, de meubles et de papier                     2348
# Tout autre Fabrication                                            510
# Matériel informatique                                             130
# Agriculture, horticulture et bétail                                61
# Name: bvd_sector, dtype: int64

# %%
# Remove industries with less than 1000 reviews
to_remove = sector_counts[sector_counts < 1000]
to_remove.index
# Out:
# Index(['Tout autre Fabrication', 'Matériel informatique',
#        'Agriculture, horticulture et bétail'],
#       dtype='object')

# %%
orbis_gd = orbis_gd[~orbis_gd['bvd_sector'].isin(to_remove.index)]

# %%
# Convert the Timestamp column to datetime format
orbis_gd['review_datetime'] = pd.to_datetime(orbis_gd['review_datetime'])

# Enough rating from mid 2016, remove before
orbis_gd = orbis_gd[orbis_gd['review_datetime'] > datetime(2017, 6, 1)]

# Diversity and inclusion starts only in mid 2020
orbis_gd.loc[orbis_gd['review_datetime'] < datetime(2021, 1, 1), 'rating_diversity_inclusion'] = np.nan

# %%
# Parsing went wrong for 232 reviews
print(len(orbis_gd['review_overall'].unique()))

# convert non-numeric values to NaN
orbis_gd['review_overall'] = pd.to_numeric(orbis_gd['review_overall'], errors='coerce')

# replace NaN values with a specific value, if desired
orbis_gd['review_overall'].fillna(value=np.nan, inplace=True)

print(len(orbis_gd['review_overall'].unique()))
# Out:
# 237
# 0    3.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: review_overall, dtype: float64
# 0    3.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: review_overall, dtype: float64
# 6

# %% [markdown]
# ### Distribution of industries

# %%
# get sample data for chatgpt
#orbis_gd[:2].to_dict()

# %%
companies_per_sector = orbis_gd.groupby('bvd_sector')['name_x'].nunique().sort_values(ascending=False)
reviews_per_sector = orbis_gd.groupby('bvd_sector')['orbis_nbr'].count().reindex(companies_per_sector.index)

fig, ax1 = plt.subplots()

# set the width of each bar
width = 0.35

# create a range of x-values for the first bar chart
x1 = np.arange(len(companies_per_sector.index))

# plot the first bar chart
ax1.bar(x1, companies_per_sector.values, color='blue', width=width, label='companies')

# set the x-tick labels for the first bar chart
ax1.set_xticks(x1)
ax1.set_xticklabels(companies_per_sector.index, rotation=90)

# set the y-axis label for the first bar chart
ax1.set_ylabel('companies', color='blue')

# create a range of x-values for the second bar chart, shifted by the width of each bar
x2 = x1 + width

# plot the second bar chart
ax2 = ax1.twinx()
ax2.bar(x2, reviews_per_sector.values, color='orange', width=width, label='reviews')

# set the x-tick labels for the second bar chart
ax2.set_xticks(x1 + width/2)
ax2.set_xticklabels(reviews_per_sector.index, rotation=90)

# set the y-axis label for the second bar chart
ax2.set_ylabel('reviews', color='orange')

# add legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Distribution of Companies and Ratings by Sector')

plt.show()

# %% [markdown]
# ### Ratings over time global

# %%
monthly_ratings = orbis_gd.groupby(pd.Grouper(key='review_datetime', freq='M'))['rating_worklifebalance',
                                                                        'rating_culture_values',
                                                                        'rating_diversity_inclusion',
                                                                        'rating_senior_leadership',
                                                                        'rating_career_opport',
                                                                        'rating_compensation_benefits'].mean()
# Enough rating from mid 2016, remove before
monthly_ratings = monthly_ratings[monthly_ratings.index > datetime(2017, 6, 1)]

# Diversity and inclusion starts only in mid 2020
monthly_ratings.loc[monthly_ratings.index < datetime(2021, 1, 1), 'rating_diversity_inclusion'] = np.nan
# Out:
# <ipython-input-13-4ca51bb4510e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   monthly_ratings = orbis_gd.groupby(pd.Grouper(key='review_datetime', freq='M'))['rating_worklifebalance',

# %%
# Plot the average ratings over time using a line plot

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(monthly_ratings.index, monthly_ratings['rating_worklifebalance'], label='Work-Life Balance')
ax.plot(monthly_ratings.index, monthly_ratings['rating_culture_values'], label='Culture and Values')
ax.plot(monthly_ratings.index, monthly_ratings['rating_diversity_inclusion'], label='Diversity and Inclusion')
ax.plot(monthly_ratings.index, monthly_ratings['rating_senior_leadership'], label='Senior Leadership')
ax.plot(monthly_ratings.index, monthly_ratings['rating_career_opport'], label='Career Opportunities')
ax.plot(monthly_ratings.index, monthly_ratings['rating_compensation_benefits'], label='Compensation and Benefits')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Average Rating')
ax.set_title('Average Ratings Over Time')
ax.legend()
plt.show()

# %% [markdown]
# ## Rating by industry over time

# %%
ratings = ['rating_worklifebalance',
        'rating_culture_values',
        'rating_diversity_inclusion',
        'rating_senior_leadership',
        'rating_career_opport',
        'rating_compensation_benefits']

# %%
sectors = orbis_gd['bvd_sector'].unique()

# %%
monthly_average_industry = {}
for sector in sectors:
    sector_data = orbis_gd[orbis_gd['bvd_sector'] == sector]
    monthly_average_industry[sector] = sector_data.groupby(pd.Grouper(key='review_datetime', freq='M'))[ratings].mean()

# %%
fig, axs = plt.subplots(nrows=12, ncols=2, figsize=(18, 30))

for rating in ratings:
    for i, sector in enumerate(sectors):
        row = i // 2
        col = i % 2
        ax = axs[row, col]
        
        ax.plot(monthly_average_industry[sector].index, monthly_average_industry[sector][rating], label=rating)
        ax.set_xlabel('Timestamp')
        ax.set_ylabel('Average rating')
        ax.set_title(f'{sector} - Average Ratings Over Time')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Interesting to see that some industries have all their ratings move together and others see differences.

# %%
orbis_gd['bvd_sector'].value_counts()
# Out:
# Services aux entreprises                                       96438
# Machines industrielles, électriques et électroniques           79594
# Banque, assurance et services financiers                       66008
# Produits chimiques, pétrole, caoutchouc et plastique           54989
# Commerce de détail                                             52063
# Communications                                                 45895
# Fabrication des produits alimentaires et de tabac              25432
# Fabrication de transport                                       20740
# Voyage, personnel et loisirs                                   16827
# Logiciel informatique                                           9414
# Industries extractives                                          9304
# Utilitaires                                                     8671
# Fabrication des textiles et des vêtements                       8453
# Transports et entreposage                                       8203
# Commerce de gros                                                5774
# Biotechnologie et sciences de la vie                            5613
# Métaux et produits métalliques                                  5316
# Administration publique, éducation, santé, services sociaux     4589
# Média et diffusion                                              4238
# Produits en cuir, pierre, argile et verre                       3974
# Construction                                                    3835
# Services immobiliers                                            3728
# Impression et Edition                                           3607
# Fabrication de bois, de meubles et de papier                    2229
# Name: bvd_sector, dtype: int64

# %% [markdown]
# Does not seem to be due by insufficent sample size.

# %% [markdown]
# Let's get this information into a table:

# %%
def std(row):
    return row.std()
def min_max(row):
    return max(row) - min(row)

# %%
stds = monthly_average_industry['Services aux entreprises'].apply(std, axis=1)
min_maxs = monthly_average_industry['Services aux entreprises'].apply(min_max, axis=1)

# %%
variability = {}

# %%
for sector in sectors:
    variability[sector] = {}
    variability[sector]['min_max'] = monthly_average_industry[sector].apply(min_max, axis=1).mean()
    variability[sector]['std'] = monthly_average_industry[sector].apply(std, axis=1).mean()

# %%
variability = pd.DataFrame.from_dict(variability, orient='index')

# %%
variability.sort_values(by=['min_max'], ascending=False)
# Out:
#                                                      min_max       std
# Impression et Edition                               0.658434  0.259751
# Logiciel informatique                               0.603153  0.246578
# Fabrication de bois, de meubles et de papier        0.584297  0.228029
# Utilitaires                                         0.506924  0.198132
# Industries extractives                              0.495576  0.195614
# Média et diffusion                                  0.488508  0.193582
# Biotechnologie et sciences de la vie                0.484876  0.190174
# Fabrication des textiles et des vêtements           0.471135  0.184108
# Produits chimiques, pétrole, caoutchouc et plas...  0.467855  0.175587
# Commerce de gros                                    0.462497  0.178359
# Produits en cuir, pierre, argile et verre           0.457097  0.179443
# Administration publique, éducation, santé, serv...  0.443456  0.173731
# Transports et entreposage                           0.441488  0.167903
# Métaux et produits métalliques                      0.441247  0.172795
# Banque, assurance et services financiers            0.430743  0.160324
# Fabrication des produits alimentaires et de tabac   0.426292  0.176362
# Commerce de détail                                  0.421664  0.158803
# Communications                                      0.419655  0.167034
# Machines industrielles, électriques et électron...  0.418927  0.163118
# Fabrication de transport                            0.411164  0.153534
# Services immobiliers                                0.396989  0.156937
# Voyage, personnel et loisirs                        0.395655  0.149298
# Services aux entreprises                            0.395491  0.149028
# Construction                                        0.394926  0.158059

# %% [markdown]
# -	Make a table showing number of firms, number of reviews, mean, median, max and min. amount of reviews and decide at how much to exclude

# %%
descriptable = orbis_gd.groupby('bvd_sector').agg(
                        review_count = ('review_id', 'count'),
                        company_count = ('name_x', 'nunique'),
                        avg_overall = ('review_overall', 'mean'),
                        avg_worklife_balance = ('rating_worklifebalance', 'mean'),
                        avg_culture_values = ('rating_culture_values', 'mean'),
                        avg_diversity_inclusion = ('rating_diversity_inclusion', 'mean'),
                        avg_senior_leadership = ('rating_senior_leadership', 'mean'),
                        avg_career_opportunities = ('rating_career_opport', 'mean'),
                        avg_compensation_benefits = ('rating_compensation_benefits', 'mean'),
                        avg_friend_recommendation = ('rating_recommend_friend', 'mean'),
                        avg_ceo = ('rating_ceo', 'mean'),
                        avg_businessoutlook = ('rating_businessoutlook', 'mean')).sort_values(by=['review_count'], ascending=False)

# %%
descriptable
# Out:
#                                                     review_count  \
# bvd_sector
# Services aux entreprises                                   96438
# Machines industrielles, électriques et électron...         79594
# Banque, assurance et services financiers                   66008
# Produits chimiques, pétrole, caoutchouc et plas...         54989
# Commerce de détail                                         52063
# Communications                                             45895
# Fabrication des produits alimentaires et de tabac          25432
# Fabrication de transport                                   20740
# Voyage, personnel et loisirs                               16827
# Logiciel informatique                                       9414
# Industries extractives                                      9304
# Utilitaires                                                 8671
# Fabrication des textiles et des vêtements                   8453
# Transports et entreposage                                   8203
# Commerce de gros                                            5774
# Biotechnologie et sciences de la vie                        5613
# Métaux et produits métalliques                              5316
# Administration publique, éducation, santé, serv...          4589
# Média et diffusion                                          4238
# Produits en cuir, pierre, argile et verre                   3974
# Construction                                                3835
# Services immobiliers                                        3728
# Impression et Edition                                       3607
# Fabrication de bois, de meubles et de papier                2229
#
#                                                     company_count  \
# bvd_sector
# Services aux entreprises                                       67
# Machines industrielles, électriques et électron...             81
# Banque, assurance et services financiers                       84
# Produits chimiques, pétrole, caoutchouc et plas...             65
# Commerce de détail                                             26
# Communications                                                 37
# Fabrication des produits alimentaires et de tabac              30
# Fabrication de transport                                       29
# Voyage, personnel et loisirs                                   18
# Logiciel informatique                                          10
# Industries extractives                                         20
# Utilitaires                                                    23
# Fabrication des textiles et des vêtements                      14
# Transports et entreposage                                      22
# Commerce de gros                                               13
# Biotechnologie et sciences de la vie                           10
# Métaux et produits métalliques                                 17
# Administration publique, éducation, santé, serv...              7
# Média et diffusion                                             10
# Produits en cuir, pierre, argile et verre                      12
# Construction                                                   17
# Services immobiliers                                            9
# Impression et Edition                                           6
# Fabrication de bois, de meubles et de papier                    9
#
#                                                     avg_overall  \
# bvd_sector
# Services aux entreprises                               3.741399
# Machines industrielles, électriques et électron...     3.932332
# Banque, assurance et services financiers               3.755371
# Produits chimiques, pétrole, caoutchouc et plas...     3.863500
# Commerce de détail                                     3.614390
# Communications                                         3.900708
# Fabrication des produits alimentaires et de tabac      3.871186
# Fabrication de transport                               3.786596
# Voyage, personnel et loisirs                           3.557259
# Logiciel informatique                                  3.945188
# Industries extractives                                 3.691745
# Utilitaires                                            3.635106
# Fabrication des textiles et des vêtements              3.675027
# Transports et entreposage                              3.760819
# Commerce de gros                                       3.533599
# Biotechnologie et sciences de la vie                   3.400321
# Métaux et produits métalliques                         3.521445
# Administration publique, éducation, santé, serv...     3.735672
# Média et diffusion                                     4.068664
# Produits en cuir, pierre, argile et verre              3.689733
# Construction                                           3.785919
# Services immobiliers                                   3.585569
# Impression et Edition                                  3.548933
# Fabrication de bois, de meubles et de papier           3.451323
#
#                                                     avg_worklife_balance  \
# bvd_sector
# Services aux entreprises                                        2.822964
# Machines industrielles, électriques et électron...              3.119142
# Banque, assurance et services financiers                        2.852245
# Produits chimiques, pétrole, caoutchouc et plas...              2.918729
# Commerce de détail                                              2.403454
# Communications                                                  3.061118
# Fabrication des produits alimentaires et de tabac               2.716106
# Fabrication de transport                                        2.780665
# Voyage, personnel et loisirs                                    2.533369
# Logiciel informatique                                           3.380497
# Industries extractives                                          2.849420
# Utilitaires                                                     2.943028
# Fabrication des textiles et des vêtements                       2.514137
# Transports et entreposage                                       2.845422
# Commerce de gros                                                2.841011
# Biotechnologie et sciences de la vie                            2.718154
# Métaux et produits métalliques                                  2.708239
# Administration publique, éducation, santé, serv...              2.886250
# Média et diffusion                                              2.929212
# Produits en cuir, pierre, argile et verre                       2.748113
# Construction                                                    2.827640
# Services immobiliers                                            2.758852
# Impression et Edition                                           2.962296
# Fabrication de bois, de meubles et de papier                    2.575146
#
#                                                     avg_culture_values  \
# bvd_sector
# Services aux entreprises                                      2.861901
# Machines industrielles, électriques et électron...            3.188431
# Banque, assurance et services financiers                      2.812705
# Produits chimiques, pétrole, caoutchouc et plas...            3.010857
# Commerce de détail                                            2.446594
# Communications                                                3.128816
# Fabrication des produits alimentaires et de tabac             3.029097
# Fabrication de transport                                      2.746336
# Voyage, personnel et loisirs                                  2.691329
# Logiciel informatique                                         3.309220
# Industries extractives                                        2.804170
# Utilitaires                                                   2.871295
# Fabrication des textiles et des vêtements                     2.677393
# Transports et entreposage                                     2.947458
# Commerce de gros                                              2.823173
# Biotechnologie et sciences de la vie                          2.696063
# Métaux et produits métalliques                                2.744545
# Administration publique, éducation, santé, serv...            2.926128
# Média et diffusion                                            3.201746
# Produits en cuir, pierre, argile et verre                     2.809763
# Construction                                                  3.042503
# Services immobiliers                                          2.709227
# Impression et Edition                                         2.799834
# Fabrication de bois, de meubles et de papier                  2.694033
#
#                                                     avg_diversity_inclusion  \
# bvd_sector
# Services aux entreprises                                           2.904431
# Machines industrielles, électriques et électron...                 3.129332
# Banque, assurance et services financiers                           2.872343
# Produits chimiques, pétrole, caoutchouc et plas...                 3.024010
# Commerce de détail                                                 2.577690
# Communications                                                     3.257775
# Fabrication des produits alimentaires et de tabac                  3.008807
# Fabrication de transport                                           2.818573
# Voyage, personnel et loisirs                                       2.855077
# Logiciel informatique                                              3.363889
# Industries extractives                                             2.803973
# Utilitaires                                                        2.973529
# Fabrication des textiles et des vêtements                          2.764201
# Transports et entreposage                                          3.115121
# Commerce de gros                                                   2.986045
# Biotechnologie et sciences de la vie                               2.895957
# Métaux et produits métalliques                                     2.786552
# Administration publique, éducation, santé, serv...                 2.992821
# Média et diffusion                                                 3.020285
# Produits en cuir, pierre, argile et verre                          2.803819
# Construction                                                       2.965438
# Services immobiliers                                               2.824725
# Impression et Edition                                              2.894756
# Fabrication de bois, de meubles et de papier                       2.688699
#
#                                                     avg_senior_leadership  \
# bvd_sector
# Services aux entreprises                                         2.553112
# Machines industrielles, électriques et électron...               2.816029
# Banque, assurance et services financiers                         2.514407
# Produits chimiques, pétrole, caoutchouc et plas...               2.663278
# Commerce de détail                                               2.171811
# Communications                                                   2.824905
# Fabrication des produits alimentaires et de tabac                2.688070
# Fabrication de transport                                         2.489634
# Voyage, personnel et loisirs                                     2.484816
# Logiciel informatique                                            2.920013
# Industries extractives                                           2.469798
# Utilitaires                                                      2.533041
# Fabrication des textiles et des vêtements                        2.343073
# Transports et entreposage                                        2.636231
# Commerce de gros                                                 2.538448
# Biotechnologie et sciences de la vie                             2.448780
# Métaux et produits métalliques                                   2.509217
# Administration publique, éducation, santé, serv...               2.639573
# Média et diffusion                                               2.822322
# Produits en cuir, pierre, argile et verre                        2.533468
# Construction                                                     2.853455
# Services immobiliers                                             2.552039
# Impression et Edition                                            2.466593
# Fabrication de bois, de meubles et de papier                     2.445043
#
#                                                     avg_career_opportunities  \
# bvd_sector
# Services aux entreprises                                            2.777743
# Machines industrielles, électriques et électron...                  3.037993
# Banque, assurance et services financiers                            2.695794
# Produits chimiques, pétrole, caoutchouc et plas...                  2.873393
# Commerce de détail                                                  2.294067
# Communications                                                      2.994727
# Fabrication des produits alimentaires et de tabac                   2.906692
# Fabrication de transport                                            2.765911
# Voyage, personnel et loisirs                                        2.674689
# Logiciel informatique                                               3.080943
# Industries extractives                                              2.681857
# Utilitaires                                                         2.734979
# Fabrication des textiles et des vêtements                           2.484917
# Transports et entreposage                                           2.927466
# Commerce de gros                                                    2.688258
# Biotechnologie et sciences de la vie                                2.601105
# Métaux et produits métalliques                                      2.700339
# Administration publique, éducation, santé, serv...                  2.799085
# Média et diffusion                                                  2.994809
# Produits en cuir, pierre, argile et verre                           2.747358
# Construction                                                        3.035202
# Services immobiliers                                                2.707350
# Impression et Edition                                               2.550873
# Fabrication de bois, de meubles et de papier                        2.651862
#
#                                                     avg_compensation_benefits  \
# bvd_sector
# Services aux entreprises                                             2.738599
# Machines industrielles, électriques et électron...                   3.056135
# Banque, assurance et services financiers                             2.696325
# Produits chimiques, pétrole, caoutchouc et plas...                   3.055775
# Commerce de détail                                                   2.341125
# Communications                                                       2.944133
# Fabrication des produits alimentaires et de tabac                    2.979632
# Fabrication de transport                                             2.766924
# Voyage, personnel et loisirs                                         2.610091
# Logiciel informatique                                                3.001381
# Industries extractives                                               2.861995
# Utilitaires                                                          2.857917
# Fabrication des textiles et des vêtements                            2.628298
# Transports et entreposage                                            2.840912
# Commerce de gros                                                     2.832006
# Biotechnologie et sciences de la vie                                 2.572065
# Métaux et produits métalliques                                       2.875470
# Administration publique, éducation, santé, serv...                   2.788189
# Média et diffusion                                                   2.979943
# Produits en cuir, pierre, argile et verre                            2.854303
# Construction                                                         3.005476
# Services immobiliers                                                 2.672747
# Impression et Edition                                                2.621292
# Fabrication de bois, de meubles et de papier                         2.865410
#
#                                                     avg_friend_recommendation  \
# bvd_sector
# Services aux entreprises                                             0.441958
# Machines industrielles, électriques et électron...                   0.573805
# Banque, assurance et services financiers                             0.444830
# Produits chimiques, pétrole, caoutchouc et plas...                   0.518826
# Commerce de détail                                                   0.336648
# Communications                                                       0.536952
# Fabrication des produits alimentaires et de tabac                    0.533537
# Fabrication de transport                                             0.465813
# Voyage, personnel et loisirs                                         0.284831
# Logiciel informatique                                                0.624113
# Industries extractives                                               0.402601
# Utilitaires                                                          0.366142
# Fabrication des textiles et des vêtements                            0.338934
# Transports et entreposage                                            0.430356
# Commerce de gros                                                     0.299384
# Biotechnologie et sciences de la vie                                 0.252297
# Métaux et produits métalliques                                       0.298465
# Administration publique, éducation, santé, serv...                   0.430315
# Média et diffusion                                                   0.617792
# Produits en cuir, pierre, argile et verre                            0.400707
# Construction                                                         0.458599
# Services immobiliers                                                 0.308337
# Impression et Edition                                                0.335451
# Fabrication de bois, de meubles et de papier                         0.239013
#
#                                                      avg_ceo  \
# bvd_sector
# Services aux entreprises                            0.675339
# Machines industrielles, électriques et électron...  0.766653
# Banque, assurance et services financiers            0.646261
# Produits chimiques, pétrole, caoutchouc et plas...  0.712124
# Commerce de détail                                  0.440378
# Communications                                      0.730490
# Fabrication des produits alimentaires et de tabac   0.751142
# Fabrication de transport                            0.682375
# Voyage, personnel et loisirs                        0.503115
# Logiciel informatique                               0.772867
# Industries extractives                              0.562565
# Utilitaires                                         0.580645
# Fabrication des textiles et des vêtements           0.559846
# Transports et entreposage                           0.563806
# Commerce de gros                                    0.554116
# Biotechnologie et sciences de la vie                0.502267
# Métaux et produits métalliques                      0.563488
# Administration publique, éducation, santé, serv...  0.718310
# Média et diffusion                                  0.809524
# Produits en cuir, pierre, argile et verre           0.630701
# Construction                                        0.697674
# Services immobiliers                                0.617671
# Impression et Edition                               0.579137
# Fabrication de bois, de meubles et de papier        0.561960
#
#                                                     avg_businessoutlook
# bvd_sector
# Services aux entreprises                                       0.434078
# Machines industrielles, électriques et électron...             0.557317
# Banque, assurance et services financiers                       0.374520
# Produits chimiques, pétrole, caoutchouc et plas...             0.496997
# Commerce de détail                                             0.268272
# Communications                                                 0.499834
# Fabrication des produits alimentaires et de tabac              0.514351
# Fabrication de transport                                       0.396360
# Voyage, personnel et loisirs                                   0.282955
# Logiciel informatique                                          0.550882
# Industries extractives                                         0.343962
# Utilitaires                                                    0.334088
# Fabrication des textiles et des vêtements                      0.333996
# Transports et entreposage                                      0.480846
# Commerce de gros                                               0.313572
# Biotechnologie et sciences de la vie                           0.381102
# Métaux et produits métalliques                                 0.308799
# Administration publique, éducation, santé, serv...             0.484353
# Média et diffusion                                             0.530860
# Produits en cuir, pierre, argile et verre                      0.443822
# Construction                                                   0.503168
# Services immobiliers                                           0.328620
# Impression et Edition                                          0.304142
# Fabrication de bois, de meubles et de papier                   0.335009
